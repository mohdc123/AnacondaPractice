# %%
import pandas as pd

student_data_to_load = "students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_names = student_data_df.student_name.tolist()

# %%
student_to_fix=[]

for name in student_names:
    
    if len(name.split()) >=3:
        student_to_fix.append(name)
len(student_to_fix)
# Out:
# 1531

# %%
student_to_fix
# Out:
# ['Mr. Dylan Taylor MD',
#  'Mrs. Elizabeth Espinoza DDS',
#  'Dr. Xavier Bell II',
#  'Mr. Roberto Wright MD',
#  'Mrs. Catherine Williams MD',
#  'Mr. Timothy Harper MD',
#  'Mrs. Marcia Jones PhD',
#  'Mrs. Dawn Olson DDS',
#  'Mr. Juan Bryant II',
#  'Mrs. Maria Smith DDS',
#  'Miss Tara Banks DDS',
#  'Miss Colleen Stewart DDS',
#  'Mr. Todd Greene PhD',
#  'Mrs. Alicia Kelly DDS',
#  'Mr. Michael Norton Jr.',
#  'Mr. Sean Pena Jr.',
#  'Dr. Juan Cobb MD',
#  'Mr. Justin Mullins DDS',
#  'Mr. Steven Snyder PhD',
#  'Mrs. Rebecca Martin DVM',
#  'Mr. Jason Daugherty Jr.',
#  'Mrs. Natalie Holder MD',
#  'Mrs. Susan Chase DDS',
#  'Mr. Alex Gonzales DDS',
#  'Mr. Joshua Jensen MD',
#  'Ms. Vanessa Ortiz DDS',
#  'Dr. Jimmy Smith MD',
#  'Dr. Jennifer Ramirez MD',
#  'Mrs. Amy Walker MD',
#  'Mr. Michael Baker PhD',
#  'Dr. Annette Collins DDS',
#  'Mr. George Goodwin MD',
#  'Mrs. Jennifer Martin DDS',
#  'Mrs. Kara Rodriguez DDS',
#  'Mr. Samuel Robertson DVM',
#  'Mrs. Ashley Porter DDS',
#  'Mr. Nicholas Rodriguez DVM',
#  'Ms. Sarah Ray DVM',
#  'Mr. Jason Chavez MD',
#  'Mr. Michael Chapman DDS',
#  'Dr. Brian Matthews Jr.',
#  'Dr. Jessica Fowler MD',
#  'Mrs. Laura Malone MD',
#  'Dr. Gabriel Flores MD',
#  'Ms. Sarah Mcintosh DVM',
#  'Dr. Ellen Mcclure DDS',
#  'Mr. Daniel Smith DVM',
#  'Mrs. Cynthia Martinez DDS',
#  'Dr. Marcus Kim MD',
#  'Dr. Jennifer Martinez MD',
#  'Mrs. Jennifer Tucker DDS',
#  'Mr. Raymond Cox Jr.',
#  'Dr. Jonathan Woods PhD',
#  'Mr. Brian Poole V',
#  'Dr. Melissa Allen PhD',
#  'Dr. Shane Gilmore MD',
#  'Mr. Dennis Gibson Jr.',
#  'Mrs. Sherry Flores MD',
#  'Dr. Tiffany Peters DDS',
#  'Miss Stephanie Perry DVM',
#  'Mr. Thomas Smith MD',
#  'Dr. Sean Duncan MD',
#  'Dr. Jennifer Campbell MD',
#  'Mrs. Bonnie Boyd PhD',
#  'Dr. Eric Lambert PhD',
#  'Mrs. Michelle Dickerson DDS',
#  'Dr. Emily Gutierrez DDS',
#  'Dr. Ryan Orozco DVM',
#  'Mr. Keith Peters DDS',
#  'Mrs. Renee Thomas DDS',
#  'Dr. Shannon Johnson MD',
#  'Mrs. Deborah Walters PhD',
#  'Mrs. Anna Everett MD',
#  'Mrs. Robin Lopez MD',
#  'Mrs. Molly Lopez MD',
#  'Mr. Juan Buckley DDS',
#  'Mrs. Megan Kaufman DVM',
#  'Dr. Chelsey Williams MD',
#  'Mrs. Brooke Henry DDS',
#  'Mr. Derrick Campbell DDS',
#  'Mr. Joseph Knight DDS',
#  'Mrs. Brittany Duncan MD',
#  'Mrs. Jennifer Edwards DVM',
#  'Mrs. Brenda Bishop MD',
#  'Mrs. Kathleen Johnson DVM',
#  'Mr. Martin Hensley DDS',
#  'Mr. Alexander Foster MD',
#  'Mr. Larry Francis MD',
#  'Miss Erin Bradley DDS',
#  'Mrs. Kimberly Key DDS',
#  'Mr. Jason Grant DDS',
#  'Mr. Daniel Mckinney Jr.',
#  'Mrs. Bethany Fisher PhD',
#  'Mr. Daniel Nguyen DDS',
#  'Mr. Michael Dyer MD',
#  'Dr. Oscar Lawson MD',
#  'Mrs. Katie Weber MD',
#  'Mrs. Sheena Bailey DVM',
#  'Mr. Andrew Mitchell V',
#  'Mrs. Pam Lewis DVM',
#  'Mr. Jeremiah Morris IV',
#  'Mr. David Morales Jr.',
#  'Mrs. Lori Rogers MD',
#  'Mrs. Christina Mitchell DDS',
#  'Mr. Jason Lopez Jr.',
#  'Dr. Seth Villarreal DVM',
#  'Mrs. Sabrina Murillo MD',
#  'Mrs. Brenda Johnson DVM',
#  'Dr. Alexander Chang PhD',
#  'Ms. Stephanie Schwartz DDS',
#  'Dr. Devin Sharp PhD',
#  'Miss Chelsea Sullivan PhD',
#  'Dr. Jessica Love DVM',
#  'Mr. Colton Collins II',
#  'Mr. Mason Hernandez MD',
#  'Dr. Bradley Jones DDS',
#  'Dr. Jennifer Thomas DDS',
#  'Mr. Sean Coleman PhD',
#  'Dr. Sheila Walton MD',
#  'Mr. Gary Anderson DDS',
#  'Dr. Matthew Cooper DDS',
#  'Mr. Michael Martin DVM',
#  'Mrs. Kaitlin Oconnor DVM',
#  'Mrs. Brittany Ford DDS',
#  'Mrs. Wendy Gomez DVM',
#  'Dr. Brian Harrington DVM',
#  'Mrs. Jordan White MD',
#  'Dr. Jacob Taylor MD',
#  'Ms. Alicia Zhang DDS',
#  'Mrs. Melissa Ingram DDS',
#  'Mrs. Melanie Martinez PhD',
#  'Mrs. Megan Clark MD',
#  'Dr. Jennifer Hogan MD',
#  'Mr. Joshua Thompson Jr.',
#  'Dr. Tina White PhD',
#  'Mrs. Kimberly Floyd DDS',
#  'Ms. Karen Villegas MD',
#  'Dr. Aaron Morrison MD',
#  'Mrs. Dana Hammond DDS',
#  'Mr. Duane Roberts MD',
#  'Mrs. Lisa Lyons MD',
#  'Dr. Philip Jones Jr.',
#  'Mrs. Mary Duarte MD',
#  'Dr. David Robinson DVM',
#  'Mr. Joseph Marquez Jr.',
#  'Dr. Lauren Robertson MD',
#  'Dr. Theresa Gaines MD',
#  'Mr. Isaiah Martinez DDS',
#  'Mrs. Karen Wright MD',
#  'Dr. Brianna Greene MD',
#  'Miss Jessica Holloway DVM',
#  'Mrs. Rachel Newman DDS',
#  'Mrs. Amy Bradford DDS',
#  'Dr. Bridget Hart DVM',
#  'Mr. Mark Peters DDS',
#  'Miss Hannah Moore MD',
#  'Mrs. Shannon Gonzalez MD',
#  'Mrs. Jennifer Chavez DVM',
#  'Mrs. Lisa Vargas DDS',
#  'Mr. Richard Curry PhD',
#  'Mrs. Brittany Boone MD',
#  'Dr. Wesley Lynch MD',
#  'Dr. Kristi Soto MD',
#  'Dr. Raven Ortiz MD',
#  'Mr. Patrick Rodriguez MD',
#  'Mr. James Thompson MD',
#  'Mrs. Adrienne Evans DDS',
#  'Dr. Luke Torres DVM',
#  'Mr. George Hess Jr.',
#  'Mr. Brian Schmidt DVM',
#  'Mr. Joseph Matthews III',
#  'Mrs. Brenda Henderson DVM',
#  'Dr. Dylan Bailey Jr.',
#  'Mrs. Amanda Harris DDS',
#  'Mr. Chad Gentry DDS',
#  'Dr. Jenna Arellano MD',
#  'Mrs. Amber Garner DVM',
#  'Dr. Dana Burnett MD',
#  'Mrs. Chelsea Roberts MD',
#  'Dr. Andrea Welch DDS',
#  'Mrs. Brittany Perry MD',
#  'Ms. Hannah Mcdonald MD',
#  'Ms. Stephanie Nichols DVM',
#  'Dr. Jay Johnson DDS',
#  'Mr. Wesley Fields MD',
#  'Mrs. Pam Wolf DDS',
#  'Mr. Jason Patel Jr.',
#  'Dr. Michael Sullivan DDS',
#  'Mrs. Brittney Schultz DVM']

# %%
prefixes = []
for name in student_to_fix:
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])

set(prefixes)
# Out:
# {'Adam',
#  'Amy',
#  'Anna',
#  'Anne',
#  'Carl',
#  'Chad',
#  'Cody',
#  'Cory',
#  'Dale',
#  'Dana',
#  'Dawn',
#  'Dr.',
#  'Emma',
#  'Eric',
#  'Erik',
#  'Erin',
#  'Gail',
#  'Gary',
#  'Gina',
#  'Greg',
#  'Ian',
#  'Jill',
#  'Jodi',
#  'Joe',
#  'John',
#  'Jon',
#  'Jose',
#  'Judy',
#  'Kara',
#  'Kari',
#  'Kim',
#  'Kyle',
#  'Leah',
#  'Lisa',
#  'Lori',
#  'Luke',
#  'Lynn',
#  'Marc',
#  'Mark',
#  'Mary',
#  'Mike',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Ms.',
#  'Noah',
#  'Omar',
#  'Paul',
#  'Ruth',
#  'Ryan',
#  'Sara',
#  'Sean',
#  'Seth',
#  'Tara',
#  'Tina',
#  'Todd',
#  'Toni',
#  'Tony',
#  'Troy'}

# %%
suffixes = []

for name in student_to_fix:
    if len(name.split()[-1])<=3:
        suffixes.append(name.split()[-1])
        
set(suffixes)
# Out:
# {'Cox',
#  'DDS',
#  'DVM',
#  'Day',
#  'II',
#  'III',
#  'IV',
#  'Jr.',
#  'Kim',
#  'Lee',
#  'Li',
#  'MD',
#  'PhD',
#  'Roy',
#  'V'}

# %%
#removing undesired prefixes and suffixes

# Add each prefix and suffix to remove to a list.

prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# Iterate through the "prefixes_suffixes" list and replace them with an empty space, "" when it appears in the student's name.

for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
student_data_df
# Out:
# C:\Users\mohd_\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   # Remove the CWD from sys.path while we load stuff.
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# 3                 67          58
# 4                 97          84
# ...              ...         ...
# 39165             99          90
# 39166             95          70
# 39167             73          84
# 39168             99          90
# 39169             95          75
#
# [39170 rows x 7 columns]
