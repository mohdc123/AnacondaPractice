# %%
# Add the Pandas dependency.
import pandas as pd
import os
import pathlib
pathlib.Path().resolve()
schoollist_csv = "schools_complete.csv"
stdlist_csv =  "students_complete.csv"
#read csv file using pandas function read_csv()

school_data_df = pd.read_csv(schoollist_csv)
school_data_df
student_data_df = pd.read_csv(stdlist_csv)
school_data_df
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
student_data_df.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
student_data_df.isnull().sum()
# Out:
# Student ID       0
# student_name     0
# gender           0
# grade            0
# school_name      0
# reading_score    0
# math_score       0
# dtype: int64

# %%
student_data_df.notnull()
# Out:
#        Student ID  student_name  gender  grade  school_name  reading_score  \
# 0            True          True    True   True         True           True
# 1            True          True    True   True         True           True
# 2            True          True    True   True         True           True
# 3            True          True    True   True         True           True
# 4            True          True    True   True         True           True
# ...           ...           ...     ...    ...          ...            ...
# 39165        True          True    True   True         True           True
# 39166        True          True    True   True         True           True
# 39167        True          True    True   True         True           True
# 39168        True          True    True   True         True           True
# 39169        True          True    True   True         True           True
#
#        math_score
# 0            True
# 1            True
# ...

# %%
student_data_df.notnull().sum()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# Iterate through the words in the "prefixes_suffixes" list and replace them with an empty space, "".
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
student_data_df
# Out:
# C:\Users\mohd_\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# ...

# %%
# write cleaned data to a csv file.

student_data_df.to_csv("CleanedStundentData.csv")

# %%
student_data_df.iloc[4][1]
# Out:
# 'Bonnie Ray'

# %%
for index, row in student_data_df.iterrows():
      print(index, row['student_name'])
# Out:
# 0 Paul Bradley
# 1 Victor Smith
# 2 Kevin Rodriguez
# 3 Richard Scott
# 4 Bonnie Ray
# 5 Bryan Miranda
# 6 Sheena Carter
# 7 Nicole Baker
# 8 Michael Roth
# 9 Matthew Greene
# 10 Andrew Alexander
# 11 Daniel Cooper
# 12 Brittney Walker
# 13 William Long
# 14 Tammy Hebert
# 15 Jordan Carson
# 16 Donald Zamora
# 17 Kimberly Santiago
# 18 Kevin Stevens
# 19 Brandi Lyons
# 20 Lisa Davis
# 21 Kristen Lopez
# 22 Kimberly Stewart
# 23 Christopher Parker
# 24 Chelsea Griffith
# 25 Cesar Morris
# 26 Melanie Decker
# 27 Tracey Oconnor
# 28 Kelly James
# 29 Nicole Brown
# 30 Bobby Harris
# 31 Brian Fernandez
# 32 Candace Phelps
# 33 Amy Gonzalez
# 34 Steven Green
# 35 Benjamin Carlson
# 36 Kevin Bailey
# 37 Jesse Newton
# 38 Kimberly Mercado
# 39 Gregory Roberts
# 40 Matthew Mayer
# 41 Jennifer Parks
# 42 John Carlson
# 43 Megan Roberts
# 44 Debra Flores
# 45 Heidi Jackson
# 46 Denise Bradford
# 47 Ellen Brown
# 48 Amy Perkins
# 49 Natalie Mitchell
# 50 Tiffany Gutierrez
# 51 Jennifer Hess
# ...

# %%
student_data_df.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score'],
#       dtype='object')

# %%
student_data_df.loc(student_data_df["Student ID"] < 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8920\2778482693.py in <module>
# ----> 1 student_data_df.loc(student_data_df["Student ID"] < 10)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     635
#     636         if axis is not None:
# --> 637             axis = self.obj._get_axis_number(axis)
#     638         new_self.axis = axis
#     639         return new_self
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     544     def _get_axis_number(cls, axis: Axis) -> int:
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#     548             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'

# %%
merged_df = pd.merge(school_data_df, student_data_df)

# %%
merged_df
# Out:
#        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# ...          ...                 ...       ...   ...      ...         ...
# 39165         14  Thomas High School   Charter  1635  1043130       39165
# 39166         14  Thomas High School   Charter  1635  1043130       39166
# 39167         14  Thomas High School   Charter  1635  1043130       39167
# 39168         14  Thomas High School   Charter  1635  1043130       39168
# 39169         14  Thomas High School   Charter  1635  1043130       39169
#
#           student_name gender grade  reading_score  math_score
# ...

# %%
school_data_complete_df = pd.merge(student_data_df, school_data_df, on=['school_name','school_name'])
school_data_complete_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
student_count = school_data_complete_df.count()
student_count
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# School ID        39170
# type             39170
# size             39170
# budget           39170
# dtype: int64

# %%
student_count = school_data_complete_df["Student ID"].count()
student_count
# Out:
# 39170

# %%
school_count = len(school_data_complete_df["school_name"].unique())
school_count
# Out:
# 15

# %%
total_budget = school_data_df["budget"].sum()
total_budget
# Out:
# 24649428

# %%
  school_data_complete_df.groupby(by="school_name")["reading_score","math_score"].mean()
# Out:
# C:\Users\mohd_\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                        reading_score  math_score
# school_name
# Bailey High School         81.033963   77.048432
# Cabrera High School        83.975780   83.061895
# Figueroa High School       81.158020   76.711767
# Ford High School           80.746258   77.102592
# Griffin High School        83.816757   83.351499
# Hernandez High School      80.934412   77.289752
# Holden High School         83.814988   83.803279
# Huang High School          81.182722   76.629414
# Johnson High School        80.966394   77.072464
# Pena High School           84.044699   83.839917
# Rodriguez High School      80.744686   76.842711
# Shelton High School        83.725724   83.359455
# Thomas High School         83.848930   83.418349
# ...

# %%
  school_data_complete_df[["reading_score","math_score"]].mean()
# Out:
# reading_score    81.877840
# math_score       78.985371
# dtype: float64

# %%
average_readling_score=school_data_complete_df["reading_score"].mean()
average_readling_score
# Out:
# 81.87784018381414

# %%
average_math_score = school_data_complete_df["math_score"].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
(school_data_complete_df["reading_score"] >=70)
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 39165     True
# 39166     True
# 39167     True
# 39168     True
# 39169     True
# Name: reading_score, Length: 39170, dtype: bool

# %%
passing_reading = school_data_complete_df[school_data_complete_df["reading_score"] >=70]
passing_reading
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1                 94          61          0  District  2917  1910635
# ...

# %%
# reading level  passed student count
total_passing_reading = passing_reading["student_name"].count()
total_passing_reading
# Out:
# 33610

# %%
# math passing student count
passing_math = school_data_complete_df[school_data_complete_df["math_score"] >=70]
total_passing_math = passing_math["Student ID"].count()
passing_math
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
average_math_score =passing_math["math_score"].mean()
average_math_score
# Out:
# 84.4712631937351

# %%
# average passing percentage
average_readling_score = passing_reading["reading_score"].mean()
average_readling_score
# Out:
# 84.47325200833086

# %%
percent_passing_reading = (total_passing_reading /student_count) * 100
percent_passing_reading
# Out:
# 85.80546336482001

# %%
percent_passing_math = (total_passing_math /student_count) * 100
percent_passing_math
# Out:
# 74.9808526933878

# %%
# students who passed both math and reading
passing_math_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >=70 ) & (school_data_complete_df["math_score"] >=70)]
overall_passing_math_reading_count = passing_math_reading["student_name"].count()
overall_passing_math_reading_count
# Out:
# 25528

# %%
# Calculate the overall passing percentage.
overall_passing_percentage = (overall_passing_math_reading_count /student_count)* 100
overall_passing_percentage.round()
# Out:
# 65.0

# %%
# sumnmary data frame

school_district_dict = {"Total School":[school_count],
                        "Total Students": [student_count],
                        "Total Budget" : [total_budget],
                        "Average Math Score": [round(average_math_score,1)],
                        "Average Reading score":[round(average_readling_score, 1)],
                         "% Passing Math": [round(percent_passing_math)],
                        "% Passing Reading": [round(percent_passing_reading)],
                         "Overall passing percentage": [round(overall_passing_percentage)]}

school_district_summary_df = pd.DataFrame(school_district_dict)
# format larger number with ',' for 1000th separator
school_district_summary_df["Total Students"] =  school_district_summary_df["Total Students"].map("{:,}".format)
school_district_summary_df["Total Budget"] =  school_district_summary_df["Total Budget"].map("{:,.2f}".format)
school_district_summary_df
# Out:
#    Total School Total Students   Total Budget  Average Math Score  \
# 0            15         39,170  24,649,428.00                79.0
#
#    Average Reading score  % Passing Math  % Passing Reading  \
# 0                   81.9              75                 86
#
#    Overall passing percentage
# 0                          65

# %%
school_district_summary_df.iloc[0]
# Out:
# Total School                             15
# Total Students                       39,170
# Total Budget                  24,649,428.00
# Average Math Score                     79.0
# Average Reading score                  81.9
# % Passing Math                           75
# % Passing Reading                        86
# Overall passing percentage               65
# Name: 0, dtype: object

# %%
total_students = dict(student_data_df.groupby(["school_name"])["Student ID"].count())
total_students
total_student_school = list( total_students.values())
per_student_budget=[]
per_student_budget = (school_data_complete_df.groupby(["school_name"])["budget"])

# %%
total_students = list(student_data_df.groupby(["school_name"])["Student ID"].count())
total_students
per_student_budget={}
for n in range(14):
    tempdf = school_data_df.iloc[n]
#total_student_school = list( total_students.values())
#total_student_school

tempdf
# Out:
# School ID                    13
# school_name    Ford High School
# type                   District
# size                       2739
# budget                  1763916
# Name: 13, dtype: object

# %%
per_school_types = school_data_df.set_index(["school_name"])["type"]
per_school_types
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
df = pd.DataFrame(per_school_types)
df
per_school_counts = school_data_df.set_index(["school_name"])["size"]
per_school_counts
# Out:
# school_name
# Huang High School        2917
# Figueroa High School     2949
# Shelton High School      1761
# Hernandez High School    4635
# Griffin High School      1468
# Wilson High School       2283
# Cabrera High School      1858
# Bailey High School       4976
# Holden High School        427
# Pena High School          962
# Wright High School       1800
# Rodriguez High School    3999
# Johnson High School      4761
# Ford High School         2739
# Thomas High School       1635
# Name: size, dtype: int64

# %%
per_school_budget = school_data_df.set_index(["school_name"])["budget"]
per_school_budget
# Out:
# school_name
# Huang High School        1910635
# Figueroa High School     1884411
# Shelton High School      1056600
# Hernandez High School    3022020
# Griffin High School       917500
# Wilson High School       1319574
# Cabrera High School      1081356
# Bailey High School       3124928
# Holden High School        248087
# Pena High School          585858
# Wright High School       1049400
# Rodriguez High School    2547363
# Johnson High School      3094650
# Ford High School         1763916
# Thomas High School       1043130
# Name: budget, dtype: int64

# %%
per_student_budget = per_school_budget/ per_school_counts
per_student_budget
# Out:
# school_name
# Huang High School        655.0
# Figueroa High School     639.0
# Shelton High School      600.0
# Hernandez High School    652.0
# Griffin High School      625.0
# Wilson High School       578.0
# Cabrera High School      582.0
# Bailey High School       628.0
# Holden High School       581.0
# Pena High School         609.0
# Wright High School       583.0
# Rodriguez High School    637.0
# Johnson High School      650.0
# Ford High School         644.0
# Thomas High School       638.0
# dtype: float64

# %%
per_school_passing_math = passing_math.groupby("school_name")["math_score"].count()
per_school_passing_math
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: math_score, dtype: int64

# %%
per_school_passing_reading =passing_reading.groupby("school_name")["reading_score"].count()
per_school_passing_reading
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: reading_score, dtype: int64

# %%
per_school_student = school_data_complete_df.groupby("school_name")["size"].count()
per_school_student
percentage_school_passing_math = (per_school_passing_math/per_school_student) * 100
percentage_school_passing_math
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
percentage_school_passing_reading = (per_school_passing_reading/per_school_student) * 100
percentage_school_passing_reading
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
per_school_passing_both = passing_math_reading.groupby("school_name")["reading_score"].count()
per_school_passing_both
# Out:
# school_name
# Bailey High School       2719
# Cabrera High School      1697
# Figueroa High School     1569
# Ford High School         1487
# Griffin High School      1330
# Hernandez High School    2481
# Holden High School        381
# Huang High School        1561
# Johnson High School      2549
# Pena High School          871
# Rodriguez High School    2119
# Shelton High School      1583
# Thomas High School       1487
# Wilson High School       2068
# Wright High School       1626
# Name: reading_score, dtype: int64

# %%
precentage_school_passing_both = (per_school_passing_both/per_school_student) * 100
precentage_school_passing_both
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
average_school_reading_score = school_data_complete_df.groupby("school_name")["reading_score"].mean()
average_school_reading_score
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
average_school_math_score =  school_data_complete_df.groupby("school_name")["math_score"].mean()
average_school_math_score
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
per_school_summary_dict= pd.DataFrame({ "School Type":per_school_types , 
                                        "Total Student Budget": per_school_budget,
                                         "total Students":per_school_student, 
                                         "Per Student Budget":  per_student_budget,
                                        "Average math score": average_school_math_score,
                                         "Average Reading score": average_school_reading_score,
                                         "% Passing Math": percentage_school_passing_math,
                                         "% Passing Reading": percentage_school_passing_reading,
                                         "% Overall Passing": precentage_school_passing_both  })

per_school_summary_dict
# Out:
#                       School Type  Total Student Budget  total Students  \
# school_name
# Bailey High School       District               3124928            4976
# Cabrera High School       Charter               1081356            1858
# Figueroa High School     District               1884411            2949
# Ford High School         District               1763916            2739
# Griffin High School       Charter                917500            1468
# Hernandez High School    District               3022020            4635
# Holden High School        Charter                248087             427
# Huang High School        District               1910635            2917
# Johnson High School      District               3094650            4761
# Pena High School          Charter                585858             962
# Rodriguez High School    District               2547363            3999
# Shelton High School       Charter               1056600            1761
# ...

# %%
columnlist = ["School Type", "total Students","Total Student Budget","Per Student Budget","Average math score","Average Reading score","% Passing Math","% Passing Reading","% Overall Passing"]
per_school_summary_dict=per_school_summary_dict[columnlist]
per_school_summary_dict
# Out:
#                       School Type  total Students  Total Student Budget  \
# school_name
# Bailey High School       District            4976               3124928
# Cabrera High School       Charter            1858               1081356
# Figueroa High School     District            2949               1884411
# Ford High School         District            2739               1763916
# Griffin High School       Charter            1468                917500
# Hernandez High School    District            4635               3022020
# Holden High School        Charter             427                248087
# Huang High School        District            2917               1910635
# Johnson High School      District            4761               3094650
# Pena High School          Charter             962                585858
# Rodriguez High School    District            3999               2547363
# Shelton High School       Charter            1761               1056600
# ...

# %%
# Sort and show top five schools.
top_schools = per_school_summary_dict.sort_values(["% Overall Passing"],ascending=False)
top_schools.head(5)
# Out:
#                       School Type  total Students  Total Student Budget  \
# school_name
# Johnson High School      District            4761               3094650
# Hernandez High School    District            4635               3022020
# Huang High School        District            2917               1910635
# Figueroa High School     District            2949               1884411
# Rodriguez High School    District            3999               2547363
#
#                        Per Student Budget  Average math score  \
# school_name
# Johnson High School                 650.0           77.072464
# Hernandez High School               652.0           77.289752
# Huang High School                   655.0           76.629414
# Figueroa High School                639.0           76.711767
# Rodriguez High School               637.0           76.842711
#
#                        Average Reading score  % Passing Math  \
# school_name
# ...

# %%
bottom_schools = per_school_summary_dict.sort_values(["% Overall Passing"])
bottom_schools.head()
# Out:
#                       School Type  total Students  Total Student Budget  \
# school_name
# Rodriguez High School    District            3999               2547363
# Figueroa High School     District            2949               1884411
# Huang High School        District            2917               1910635
# Hernandez High School    District            4635               3022020
# Johnson High School      District            4761               3094650
#
#                        Per Student Budget  Average math score  \
# school_name
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading score  % Passing Math  \
# school_name
# ...
